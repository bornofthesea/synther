# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e2'
observed = 'e2.dat'
rv = -83

# %% [markdown]
# Teff 4112 logg 0.50 vmicro 3.826

# %%
# Original APSCAP parameters
speclist = ["e2.dat","e2a-1.dat"]
label = ["apo", "C=0.13, N=0.05, O=0.30"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.10, ncorr2=1.2,
    yoffset3=0.10, ncorr3=1.2,
    ylim1=(0.63,1.03),
    ylim2=(0.63,1.03),
    ylim3=(0.63,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e2_cno.png')

# %%
speclist = ["e2b.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.12, ncorr1=1.2,
    yoffset2=0.12, ncorr2=1.2,
    ylim1 = (0.68, 1.03), ylim2 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e2_p.png')

# %%
speclist = ["e2a-1.dat"]
label = ['[S/Fe] = 0.25']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.145, ncorr1=1.2,
    yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e2.dat", "e2a-1.dat"]
label = ["apo", '[K/Fe] = -0.08']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.1, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e2_k.png')

# %%
speclist = ["e2b.dat", "e2b-1.dat"]
label = ['[Ce/Fe] = -0.03', '[Ce/Fe] = 0.53']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.04, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.13, ncorr3=1.2,
    yoffset4=0.11, ncorr4=1.2,
    yoffset5=0.14, ncorr5=1.2,
    yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e2_ce.png')
