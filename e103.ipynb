# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e103'
observed = 'e103.dat'

# %% [markdown]
# Teff 4530.901 logg 1.337 vmicro 1.893
#
# Spectra is too noisy, finding the CNO is difficult
#
# Finding the offset on x is also difficult

# %%
# Original APSCAP parameters
speclist = ["e103xall.dat"]
label = ["[C/Fe] = -0.48, [N/Fe] = 0.37, [O/Fe] = 0.23"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=4.5, yoffset1=0.11, ncorr1=1.2,
    xoffset2=4.5, yoffset2=0.11, ncorr2=1.2,
    xoffset3=4.5, yoffset3=0.14, ncorr3=1.2,
    ylim1=(0.8,1.03),
    ylim2=(0.7,1.03),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e103_cno.png')

# %%
# Zoom out
speclist = ["e103xall.dat"]
label = ["[C/Fe] = -0.48, [N/Fe] = 0.37, [O/Fe] = 0.23"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=4.5, yoffset1=0.11, ncorr1=1.2,
    xoffset2=4.5, yoffset2=0.11, ncorr2=1.2,
    xoffset3=4.5, yoffset3=0.14, ncorr3=1.2,
    xlim1=(15501,15530),
    xlim2=(15535,15570),
    xlim3=(15570,15599),
    ylim1=(0,1.6),
    ylim2=(0,3),
    ylim3=(0,3)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e103_cno.png')

# %%
speclist = ["e103xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=4.1, yoffset1=0.1, ncorr1=1.2,
    xoffset2=4.1, yoffset2=0.05, ncorr2=1.2,
    ylim1 = (0.5, 1.1), ylim2 = (0.5, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e103_p.png')

# %%
speclist = ["e103xb.dat"]
label = ['[S/Fe] = -0.03']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-4.5, yoffset1=0.13, ncorr1=1.2,
    xoffset2=-4.5, yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.8, 1.1), ylim2 = (0.8, 1.1)
)

speclist = ["e103xb.dat"]
label = ['[K/Fe] = -1.06']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-4.5, yoffset1=0.14, ncorr1=1.2,
    ylim1 = (0.8, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e103_k.png')

# %%
speclist = ["e103xa.dat"]
label = ['[Ce/Fe] = -0.57']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=6.1, yoffset1=0.11, ncorr1=1.2,
    xoffset2=6.1, yoffset2=0.11, ncorr2=1.2,
    xoffset3=6.9, yoffset3=0.11, ncorr3=1.2,
    xoffset4=7.2, yoffset4=0.135, ncorr4=1.2,
    xoffset5=7.3, yoffset5=0.13, ncorr5=1.2,
    xoffset6=7.3, yoffset6=0.135, ncorr6=1.2,
    ylim1 = (0.7, 1.2), ylim2 = (0.6, 1.1),
    ylim3 = (0.8, 1.1), ylim4 = (0.8, 1.1),
    ylim5 = (0.8, 1.1), ylim6 = (0.8, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e103_ce.png')
