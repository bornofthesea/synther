# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir
starname = 'e98'
observed = 'e98.dat'

# %% [markdown]
# Teff 4150.054 logg 1.02 vmicro 1.889
#
# C and O band fit
#
# Solar P
#
# Possible less S and K

# %%
# Original APSCAP parameters
speclist = ["e98xall.dat", "e98xall-3.dat"]
label = ["C=-0.45, O=0.03", "C=-0.25, O=0.33"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.4, yoffset1=0.15, ncorr1=1.2,
    xoffset2=-10.4, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-10.4, yoffset3=0.135, ncorr3=1.2,
    ylim1=(0.8,1.05),
    ylim2=(0.7,1.05),
    ylim3=(0.85,1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_cno.png')

# %%
speclist = ["e98xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-11.05, yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_p.png')

# %%
speclist = ["e98xb.dat", "e98xb-1.dat"]
label = ['[S/Fe] = -0.30', '[S/Fe] = -0.50']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.25, yoffset1=0.13, ncorr1=1.2,
    xoffset2=-10.4, yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.90, 1.05), ylim2 = (0.90, 1.05)
)

speclist = ["e98xb.dat", "e98xb-1.dat"]
label = ['[K/Fe] = -0.11', '[K/Fe] = -0.31']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.05, yoffset1=0.15, ncorr1=1.2,
    ylim1 = (0.90, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_k.png')
