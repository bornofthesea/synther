# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir
starname = 'e98'
observed = 'e98.dat'

# %%
# Original APSCAP parameters
speclist = ["e98xall.dat"]
label = ["[C/Fe]=-0.45, [N/Fe]=0.02, [O/Fe]=0.03"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.4, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-10.4, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-10.4, yoffset3=0.13, ncorr3=1.2,
    ylim1=(0.8,1.05),
    ylim2=(0.7,1.05),
    ylim3=(0.85,1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_cno.png')

# %%
# Original APSCAP parameters
speclist = ["e98xallcm02o013.dat"]
label = ["[C/Fe]=-0.15, [N/Fe]=0.02, [O/Fe]=0.13"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.4, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-10.4, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-10.35, yoffset3=0.12, ncorr3=1.2,
    ylim1=(0.8,1.05),
    ylim2=(0.7,1.05),
    ylim3=(0.85,1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_cno.png')

# %%
speclist = ["e98xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-11.05, yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_p.png')

# %%
speclist = ["e98xb.dat"]
label = ['[S/Fe] = 0.0']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.4, yoffset1=0.13, ncorr1=1.2,
    xoffset2=-10.4, yoffset2=0.163, ncorr2=1.2,
    ylim1 = (0.90, 1.05), ylim2 = (0.90, 1.05)
)

speclist = ["e223xb.dat"]
label = ['[K/Fe] = 0.0']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-10.4, yoffset1=0.155, ncorr1=1.2,
    ylim1 = (0.90, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e98_k.png')
