# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir
starname = 'e100'
observed = 'e100.dat'

# %%
# Original APSCAP parameters
speclist = ["e100xall.dat"]
label = ["[C/Fe] = -0.35, [N/Fe] = 0.52, [O/Fe] = 0.02"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-12.6, yoffset2=0.11, ncorr2=1.2,
    xoffset3=-12.6, yoffset3=0.14, ncorr3=1.2,
    ylim1=(0.8,1.15),
    ylim2=(0.7,1.15),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_cno.png')

# %%
speclist = ["e100xall-1.dat"]
label = ["[C/Fe] = -0.35, [N/Fe] = 0.52, [O/Fe] = 0.52"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-12.6, yoffset2=0.11, ncorr2=1.2,
    xoffset3=-12.65, yoffset3=0.145, ncorr3=1.2,
    ylim1=(0.8,1.15),
    ylim2=(0.7,1.15),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_cno.png')

# %%
speclist = ["e100xall-2.dat"]
label = ["[C/Fe] = -0.25, [N/Fe] = 0.52, [O/Fe] = 0.37"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-12.65, yoffset2=0.095, ncorr2=1.2,
    xoffset3=-12.65, yoffset3=0.135, ncorr3=1.2,
    ylim1=(0.8,1.15),
    ylim2=(0.7,1.15),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_cno.png')

# %%
speclist = ["e115xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.3, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.5, yoffset2=0.1575, ncorr2=1.2,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_p.png')

# %%
speclist = ["e223xb.dat"]
label = ['[S/Fe] = 0.0']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.0, yoffset1=0.155, ncorr1=1.2,
    xoffset2=-6.9, yoffset2=0.163, ncorr2=1.2,
    ylim1 = (0.90, 1.05), ylim2 = (0.90, 1.05)
)

speclist = ["e223xb.dat"]
label = ['[K/Fe] = 0.0']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.9, yoffset1=0.155, ncorr1=1.2,
    ylim1 = (0.90, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_k.png')
