# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e100'
observed = 'e100.dat'

# %% [markdown]
# Teff 4455.495 logg 0.935 vmicro 2.983
#
# C and O fitted, more C and O than expected on ASPCAP

# %%
# Original APSCAP parameters
speclist = ["e100xall.dat"]
label = ["[C/Fe] = -0.35, [N/Fe] = 0.52, [O/Fe] = 0.02"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-12.6, yoffset2=0.11, ncorr2=1.2,
    xoffset3=-12.6, yoffset3=0.14, ncorr3=1.2,
    ylim1=(0.8,1.03),
    ylim2=(0.7,1.03),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_cno.png')

# %%
speclist = ["e100xall.dat", "e100xall-2.dat"]
label = ["[C/Fe] = -0.35, [N/Fe] = 0.52, [O/Fe] = 0.02", "[C/Fe] = -0.25, [N/Fe] = 0.52, [O/Fe] = 0.37"]
#7.52 #7.72 #8.35
plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-12.65, yoffset2=0.095, ncorr2=1.2,
    xoffset3=-12.65, yoffset3=0.135, ncorr3=1.2,
    ylim1=(0.8,1.03),
    ylim2=(0.7,1.03),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_cno.png')

# %%
speclist = ["e100xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.8, yoffset1=0.11, ncorr1=1.2,
    xoffset2=-13.5, yoffset2=0.12, ncorr2=1.2,
    ylim1 = (0.78, 1.03), ylim2 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_p.png')

# %%
speclist = ["e100xb.dat"]
label = ['[S/Fe] = -0.10']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.13, ncorr1=1.2,
    xoffset2=-12.6, yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.88, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e100xb.dat", "e100xb-1.dat"]
label = ['[K/Fe] = -0.01', '[K/Fe] = -0.21']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.4, yoffset1=0.14, ncorr1=1.2,
    ylim1 = (0.78, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_k.png')

# %%
speclist = ["e100xa.dat","e100xa-1.dat"]
label = ['[Ce/Fe] = 0.02', '[Ce/Fe] = 0.26']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.11, ncorr1=1.2,
    xoffset2=-13.2, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-13.3, yoffset3=0.14, ncorr3=1.2,
    xoffset4=-13.4, yoffset4=0.125, ncorr4=1.2,
    xoffset5=-13.5, yoffset5=0.155, ncorr5=1.2,
    xoffset6=-13.675, yoffset6=0.1625, ncorr6=1.2,
    ylim1=(0.73,1.08),
    ylim2=(0.61,1.13),
    ylim3=(0.78,1.08),
    ylim4=(0.68,1.13),
    ylim5=(0.78,1.08),
    ylim6=(0.68,1.08)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e100_ce.png')
