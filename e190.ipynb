# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir
starname = 'e190'
observed = 'e190.dat'

# %% [markdown]
# Teff 5233 logg 2.155 vmicro 1.78
#
# Very hot star, CNO lines disappear
#
# Weird possible emission or noise on PI 16482?

# %%
# Original APSCAP parameters
speclist = ["e190xall.dat"]
label = ["[C/Fe] = -0.13, [N/Fe] = 0.30, [O/Fe] = 0.46"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17.9, yoffset1=0.17, ncorr1=1.2,
    xoffset2=-17.9, yoffset2=0.14, ncorr2=1.2,
    xoffset3=-18.2, yoffset3=0.16, ncorr3=1.2,
    ylim1=(0.95,1.03),
    ylim2=(0.88,1.03),
    ylim3=(0.95,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e190_cno.png')

# %%
speclist = ["e190xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-19.1, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-19.1, yoffset2=0.16, ncorr2=1.2,
    ylim1 = (0.9, 1.1), ylim2 = (0.8, 1.3)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e190_p.png')

# %%
speclist = ["e190xb.dat"]
label = ['[S/Fe] = 0.64']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17.8, yoffset1=0.15, ncorr1=1.2,
    xoffset2=-18, yoffset2=0.16, ncorr2=1.2,
    ylim1 = (0.93, 1.03), ylim2 = (0.88, 1.03)
)

speclist = ["e190xb.dat"]
label = ['[K/Fe] = 0.50']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17.35, yoffset1=0.15, ncorr1=1.2,
    ylim1 = (0.95, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e190_k.png')
