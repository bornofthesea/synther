# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e4'
observed = 'e4.dat'
rv = -83

# %% [markdown]
# Teff 4215 logg 0.57 vmicro 3.652

# %%
# Original APSCAP parameters
speclist = ["e4-1.dat"]
label = ["C=0,N=-0.1,O=0.2"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.145, ncorr1=1.2,
    yoffset2=0.11, ncorr2=1.2,
    yoffset3=0.12, ncorr3=1.2,
    ylim1=(0.63,1.03),
    ylim2=(0.63,1.03),
    ylim3=(0.63,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e4_cno.png')

# %%
speclist = ["e4p.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.13, ncorr2=1.2,
    ylim1 = (0.63, 1.03), ylim2 = (0.63, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e4_p.png')

# %%
speclist = ["e4sk.dat"]
label = ['[S/Fe] = 0.0']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e4sk.dat"]
label = ['[K/Fe] = -0.02']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.11, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e4_k.png')

# %%
speclist = ["e4ce.dat", "e4ce-1.dat"]
label = ['[Ce/Fe] = 0.01', '[Ce/Fe] = 0.5']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.04, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.13, ncorr3=1.2,
    yoffset4=0.11, ncorr4=1.2,
    yoffset5=0.14, ncorr5=1.2,
    yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e4_ce.png')
