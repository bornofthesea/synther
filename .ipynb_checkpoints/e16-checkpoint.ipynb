# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e11'
observed = 'e11.dat'
rv = -83

# %% [markdown]
# Teff 4159 logg 0.861 vmicro 2.357

# %%
# Original APSCAP parameters
speclist = ["e11a.dat","e11a-1.dat"]
label = ["C=-.47,N=0.14,O=.05","C=-.05,N=0,O=.5"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.15, ncorr1=1.2,
    yoffset2=0.13, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    ylim1=(0.75,1.05),
    ylim2=(0.63,1.03),
    ylim3=(0.83,1.03)
)

#speclist = ["e9sk.dat"]
label = ['apo']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.16, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

#speclist = ["e9sk.dat"]
label = ['apo']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e11_k.png')

# %%
speclist = ["e11b.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.73, 1.03), ylim2 = (0.73, 1.03)
)

speclist = ["e11b.dat", "e11b-1.dat"]
label = ['[Ce/Fe] = 0.01','[Ce/Fe] = 0.50']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.09, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    yoffset4=0.13, ncorr4=1.2,
    yoffset5=0.14, ncorr5=1.2,
    yoffset6=0.13, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e11_ce.png')
