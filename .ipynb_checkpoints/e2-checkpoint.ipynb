# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e1'
observed = 'e1.dat'

# %% [markdown]
# Teff 4336 logg 0.99 vmicro 2.615

# %%
# Original APSCAP parameters
speclist = ["e1b-1.dat"]
label = ["C=-0.25, N=0.1, O=0.12"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = -307,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.10, ncorr2=1.2,
    yoffset3=0.12, ncorr3=1.2,
    ylim1=(0.63,1.03),
    ylim2=(0.63,1.03),
    ylim3=(0.63,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e1_cno.png')

# %%
speclist = ["e1a.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = -307,
    yoffset1=0.11, ncorr1=1.2,
    yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.78, 1.03), ylim2 = (0.88, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e1_p.png')

# %%
speclist = ["e1b-1.dat", "e1b-2.dat"]
label = ['[S/Fe] = 0.21', '[S/Fe] = 0.01']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = -305,
    yoffset1=0.145, ncorr1=1.2,
    yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e1b-1.dat"]
label = ['[K/Fe] = -0.12']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = -305,
    yoffset1=0.11, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e1_k.png')

# %%
speclist = ["e1a.dat"]
label = ['[Ce/Fe] = -0.66']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = -307,
    yoffset1=0.11, ncorr1=1.2,
    yoffset2=0.13, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    yoffset4=0.13, ncorr4=1.2,
    yoffset5=0.14, ncorr5=1.2,
    yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.53,1.03),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e1_ce.png')
