# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur

# %%
speclist = ["e223c-c4.dat"]  # Your synthetic files
label = ["C754 N683 O824"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1=-6.25, yoffset1=-0.005, ncorr1=1,
    xoffset2=-6.25, yoffset2=-0.025, ncorr2=1,
    xoffset3=-6.30, yoffset3=-0.015, ncorr3=1,
    ylim1=(0.85, 1.03), 
    ylim2=(0.75, 1.03), 
    ylim3=(0.9, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_cno.png')

# %%
speclist = ["e223c-c7.dat"]  # Your synthetic files
label = ["C779 N683 O814"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1=-6.25, yoffset1=-0.005, ncorr1=1,
    xoffset2=-6.25, yoffset2=-0.025, ncorr2=1,
    xoffset3=-6.30, yoffset3=-0.015, ncorr3=1,
    ylim1=(0.85, 1.03), 
    ylim2=(0.75, 1.03), 
    ylim3=(0.9, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_cno.png')

# %%
speclist = ["e223c-c7.dat"]  # Your synthetic files
label = ["C779 N683 O814"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1=-6.25, yoffset1=0.32, ncorr1=1.5,
    xoffset2=-6.25, yoffset2=0.31, ncorr2=1.5,
    xoffset3=-6.30, yoffset3=0.315, ncorr3=1.5,
    ylim1=(0.9, 1.03), 
    ylim2=(0.8, 1.03), 
    ylim3=(0.9, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_cno.png')

# %%
speclist = ["e223c-c7.dat"]  # Your synthetic files
label = ["C779 N683 O814"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1=-6.25, yoffset1=0.155, ncorr1=1.2,
    xoffset2=-6.25, yoffset2=0.14, ncorr2=1.2,
    xoffset3=-6.30, yoffset3=0.15, ncorr3=1.2,
    ylim1=(0.9, 1.03), 
    ylim2=(0.8, 1.03), 
    ylim3=(0.9, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_cno.png')

# %%
speclist = ["e223xa.dat"]
starname = 'e223'
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1 = -6.3, yoffset1 = 0.15, ncorr1 = 1.2, 
    xoffset2 = -6.7, yoffset2 = 0.15, ncorr2 = 1.2,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_p.png')

# %%
speclist = ["e223xb.dat", "e223xbs01k01.dat"]
label = ['[S/Fe] = 0.0', '[S/Fe] = 0.1']
plot_sulfur(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1 = -6.15, yoffset1 = 0.16, ncorr1 = 1.2, 
    xoffset2 = -6.15, yoffset2 = 0.16, ncorr2 = 1.2,
    ylim1 = (0.90, 1.05), ylim2 = (0.90, 1.05)
)

speclist = ["e223xb.dat", "e223xbs01k01.dat"]
label = ['[K/Fe] = 0.0', '[K/Fe] = 0.1']
plot_potassium(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1 = -5.95, yoffset1 = 0.16, ncorr1 = 1.2,
    ylim1 = (0.90, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_k.png')
