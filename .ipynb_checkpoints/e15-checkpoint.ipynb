# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e10'
observed = 'e10.dat'
rv = -83

# %% [markdown]
# Teff 4033 logg 0.554 vmicro 2.698

# %%
# Original APSCAP parameters
speclist = ["e10a-1.dat"]
label = ["C=-.1,N=0.05,O=.3"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.15, ncorr1=1.2,
    yoffset2=0.1, ncorr2=1.2,
    yoffset3=0.12, ncorr3=1.2,
    ylim1=(0.75,1.05),
    ylim2=(0.63,1.03),
    ylim3=(0.83,1.03)
)

#speclist = ["e9sk.dat"]
label = ['apo']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

#speclist = ["e9sk.dat"]
label = ['apo']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.11, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e10_k.png')

# %%
speclist = ["e10b.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.13, ncorr2=1.2,
    ylim1 = (0.73, 1.03), ylim2 = (0.73, 1.03)
)

speclist = ["e10b.dat", "e10b-1.dat"]
label = ['[Ce/Fe] = 0.0','[Ce/Fe] = 0.50']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.05, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    yoffset4=0.12, ncorr4=1.2,
    yoffset5=0.13, ncorr5=1.2,
    yoffset6=0.13, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e10_ce.png')
