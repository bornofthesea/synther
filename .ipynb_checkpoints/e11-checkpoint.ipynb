# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e9'
observed = 'e9.dat'
rv = -83

# %% [markdown]
# Teff 4444 logg 1.1 vmicro 2.553

# %%
# Original APSCAP parameters
speclist = ["e9.dat", 'e9-1.dat', 'e9-2.dat']
label = ["apo", "C=-0.25,N=0.26,O=.2", "C=-.1,N=0,O=.2"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.15, ncorr1=1.2,
    yoffset2=0.12, ncorr2=1.2,
    yoffset3=0.13, ncorr3=1.2,
    ylim1=(0.75,1.05),
    ylim2=(0.63,1.03),
    ylim3=(0.88,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e9_cno.png')

# %%
speclist = ["e9p.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.73, 1.03), ylim2 = (0.73, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e9_p.png')

# %%
speclist = ["e9sk.dat"]
label = ['apo', 'S=0']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e9sk.dat"]
label = ['apo', 'K=0']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.12, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e9_k.png')

# %%
speclist = ["e9ce.dat"]
label = ['[Ce/Fe] = 0.04','[Ce/Fe] = 0.50']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.09, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    yoffset4=0.13, ncorr4=1.2,
    yoffset5=0.15, ncorr5=1.2,
    yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e9_ce.png')
