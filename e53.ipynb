# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e53'
observed = 'e53.dat'

# %% [markdown]
# Teff 5092 logg 1.872 vmicro 2.074
#
# Hot star, CNO lines are flat
#
# P and S consistent with APSCAP
#
# Possible a bit more of K

# %%
# Original APSCAP parameters
speclist = ["e53xall.dat"]
label = ["[C/Fe]=-0.41, [N/Fe]=0.43, [O/Fe]=0.34"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.65, yoffset1=0.165, ncorr1=1.2,
    xoffset2=-12.65, yoffset2=0.139, ncorr2=1.2,
    xoffset3=-12.65, yoffset3=0.16, ncorr3=1.2,
    ylim1=(0.96,1.01),
    ylim2=(0.88,1.03),
    ylim3=(0.98,1.01)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_cno.png')

# %%
speclist = ["e53xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.135, ncorr1=1.2,
    xoffset2=-13.55, yoffset2=0.175, ncorr2=1.2,
    ylim1 = (0.93, 1.01), ylim2 = (0.93, 1.02)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_p.png')

# %%
speclist = ["e53xb.dat"]
label = ['[S/Fe] = 0.49']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.087, ncorr1=1.1,
    xoffset2=-12.6, yoffset2=0.087, ncorr2=1.1,
    ylim1 = (0.94, 1.005), ylim2 = (0.94, 1.005)
)

speclist = ["e53xb.dat"]
label = ['[K/Fe] = 0.26', '[K/Fe] = 0.51']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.45, yoffset1=0.164, ncorr1=1.2,
    ylim1 = (0.96, 1.005)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_k.png')

# %%
speclist = ["e53xa.dat"]
label = ['[Ce/Fe] = -0.66']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.75, yoffset1=0.168, ncorr1=1.2,
    xoffset2=-13, yoffset2=0.168, ncorr2=1.2,
    xoffset3=-13.5, yoffset3=0.17, ncorr3=1.2,
    xoffset4=-13.55, yoffset4=0.15, ncorr4=1.2,
    xoffset5=-12.5, yoffset5=0.17, ncorr5=1.2,
    xoffset6=-13.55, yoffset6=0.17, ncorr6=1.2,
    ylim1=(0.88,1.03),
    ylim2=(0.78,1.03),
    ylim3=(0.96,1.01),
    ylim4=(0.88,1.00),
    ylim5=(0.96,1.01),
    ylim6=(0.91,1.02)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_ce.png')
