# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir
starname = 'e53'
observed = 'e53.dat'

# %%
# Original APSCAP parameters
speclist = ["e53xall.dat"]
label = ["[C/Fe]=-0.41, [N/Fe]=0.43, [O/Fe]=0.34"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.65, yoffset1=0.091, ncorr1=1.1,
    xoffset2=-12.65, yoffset2=0.07, ncorr2=1.1,
    xoffset3=-12.65, yoffset3=0.083, ncorr3=1.1,
    ylim1=(0.95,1.03),
    ylim2=(0.9,1.03),
    ylim3=(0.95,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_cno.png')

# %%
speclist = ["e53xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.06, ncorr1=1.1,
    xoffset2=-13.55, yoffset2=0.097, ncorr2=1.1,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_p.png')

# %%
speclist = ["e53xb.dat"]
label = ['[S/Fe] = 0.49']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.087, ncorr1=1.1,
    xoffset2=-12.6, yoffset2=0.087, ncorr2=1.1,
    ylim1 = (0.90, 1.05), ylim2 = (0.90, 1.05)
)

speclist = ["e53xb.dat", "e53xbk396.dat"]
label = ['[K/Fe] = 0.26', '[K/Fe] = 0.51']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.7, yoffset1=0.088, ncorr1=1.1,
    ylim1 = (0.90, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e53_k.png')
