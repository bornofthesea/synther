# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e223'
observed = 'e223.dat'

# %% [markdown]
# Teff 4564 logg 1.804 vmicro 1.779
#
# C/Fe = 0.22 N/Fe = -0.16 O/Fe = 0.35
#
# S/Fe = 0.27 K/Fe = 0.34
#
# Run again maybe

# %%
speclist = ["e223c-c7.dat"]  # Your synthetic files
label = ["[C/Fe] = 0.22, [N/Fe] = -0.21, [O/Fe] = 0.34"]
#label = ["C779 N683 O814"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1=-6.25, yoffset1=0.155, ncorr1=1.2,
    xoffset2=-6.25, yoffset2=0.14, ncorr2=1.2,
    xoffset3=-6.30, yoffset3=0.15, ncorr3=1.2,
    ylim1=(0.9, 1.03), 
    ylim2=(0.8, 1.03), 
    ylim3=(0.9, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_cno.png')

# %%
speclist = ["e223xa.dat"]
starname = 'e223'
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1 = -6.3, yoffset1 = 0.15, ncorr1 = 1.2, 
    xoffset2 = -6.7, yoffset2 = 0.15, ncorr2 = 1.2,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_p.png')

# %%
speclist = ["e223xb.dat", "e223xbs01k01.dat"]
label = ['[S/Fe] = 0.17', '[S/Fe] = 0.27']
plot_sulfur(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1 = -6.15, yoffset1 = 0.16, ncorr1 = 1.2, 
    xoffset2 = -6.15, yoffset2 = 0.16, ncorr2 = 1.2,
    ylim1 = (0.90, 1.05), ylim2 = (0.90, 1.05)
)

speclist = ["e223xb.dat", "e223xbs01k01.dat"]
label = ['[K/Fe] = 0.24', '[K/Fe] = 0.34']
plot_potassium(
    synthetic_files=speclist,
    observed_file="e223.dat",
    labels=label,
    starname="e223",
    figsize=(5,6),
    xoffset1 = -5.95, yoffset1 = 0.16, ncorr1 = 1.2,
    ylim1 = (0.90, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_k.png')

# %%
speclist = ["e223xa.dat"]
label = ['[Ce/Fe] = -0.19']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.3, yoffset1=0.12, ncorr1=1.2,
    xoffset2=-6.4, yoffset2=0.16, ncorr2=1.2,
    xoffset3=-6.55, yoffset3=0.15, ncorr3=1.2,
    xoffset4=-6.6, yoffset4=0.15, ncorr4=1.2,
    xoffset5=-6.8, yoffset5=0.16, ncorr5=1.2,
    xoffset6=-6.8, yoffset6=0.16, ncorr6=1.2,
    ylim1=(0.71,1.01),
    ylim2=(0.63,1.13),
    ylim3=(0.78,1.08),
    ylim4=(0.73,1.13),
    ylim5=(0.83,1.08),
    ylim6=(0.63,1.08)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e223_ce.png')
