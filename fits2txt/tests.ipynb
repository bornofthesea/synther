# %%
try:
    import pyfits
except:
    from astropy.io import fits as pyfits
 
    
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import sys
import math
import os
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

# %%
file_path = '/home/morgan/PhD/Data/spectra/smc/asStar-dr17-2M01200511-7316207.fits'
hdu = pyfits.open(file_path)
hdu[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# CRVAL1  =                4.179 / Start log10(wavelength) in subsequent HDUs
# CDELT1  =                6E-06 / Dispersion in log10(wave) in subsequent HDUs
# CRPIX1  =                    1 / Pixel of starting wavelength in subsequent HDUs
# CTYPE1  = 'LOG-LINEAR'         / Logarithmic wavelength scale in subsequent HDUs
# DC-FLAG =                    1 / Logarithmic wavelength scale in subsequent HDUs
# NWAVE   =                 8575 / Number of wavelengths in subsequent HDUs
# FIELD   = 'SMC5    '           / APOGEE field name
# OBJID   = '2M01200511-7316207' / APOGEE object name
# SNR     =    303.3448080981457 / Median S/N per apStar pixel
# SNREV   =    326.5746950253363 / Median S/N per apStar pixel in middle chip
# RA      =            20.021293 / right ascension, deg, J2000
# DEC     =           -73.272423 / declination, deg, J2000
# GLON    =    300.0871305779488 / Galactic longitude
# GLAT    =   -43.69720698479416 / Galactic latitude
# J       =    10.74400043487549 / 2MASS J magnitude
# J_ERR   =  0.02300000004470348 / 2MASS J magnitude uncertainty
# H       =    10.00800037384033 / 2MASS H magnitude
# H_ERR   =  0.02400000020861626 / 2MASS H magnitude uncertainty
# K       =    9.796999931335449 / 2MASS K magnitude
# K_ERR   =  0.02099999971687794 / 2MASS K magnitude uncertainty
# SRC_H   = '2MASS   '           / source of H magnitude
# WASH_M  =      -9999.990234375
# WASH_T2 =      -9999.990234375
# DDO51   =      -9999.990234375
# IRAC_3_6=      -9999.990234375
# IRAC_4_5=      -9999.990234375
# IRAC_5_8=      -9999.990234375
# WISE_4_5=    9.814999580383301
# TARG_4_5=      -9999.990234375
# AKTARG  =  0.01780756004154682 / Extinction used for targeting
# AKMETHOD= 'SFD      '          / Extinction method using for targeting
# AKWISE  =   0.1312747299671173 / WISE all-sky extinction
# SFD_EBV =  0.05896543338894844 / SFD E(B-V)
# APTARG1 =                    0 / APOGEE_TARGET1 targeting flag
# APTARG2 =                    0 / APOGEE_TARGET2 targeting flag
# AP2TARG1=          -2147399648 / APOGEE2_TARGET1 targeting flag
# AP2TARG2=                    0 / APOGEE2_TARGET2 targeting flag
# AP2TARG3=                    0 / APOGEE2_TARGET3 targeting flag
# AP2TARG4=                    0 / APOGEE2_TARGET4 targeting flag
# NVISITS =                    3 / Number of visit spectra combined flag
# STARFLAG=                    0 / bitwise OR of individual visit starflags
# ANDFLAG =                    0 / bitwise AND of individual visit starflags
# N_COMP  =                    1 / Maximum number of components in RV CCFs
# VHELIO  =    156.5198089116421 / S/N weighted mean barycentric RV
# VSCATTER=   0.1297898729003116 / standard deviation of visit RVs
# VERR    =  0.03178195314133919 / weighted error in VHELIO
# VERR_MED=   0.0307622624460203 / median error in VHELIO
# RV_TEFF =    4119.400944330603 / Effective temperature from RV fit
# RV_LOGG =    1.871801391474221 / Surface gravity from RV fit
# RV_FEH  =  -0.7024189286918379 / Metallicity from RV fit
# RV_CHI2 =    17.14333724975586 / chisq from Doppler RV fit
# CCFWHM  =    22.39132378215838 / FWHM of RV CCF of star with template (km/s)
# AUTOFWHM=    13.83337355535812 / FWHM of RV CCF of template with template (km/s)
# MEANFIB =    31.68205833435059 / S/N weighted mean fiber number
# SIGFIB  =    25.81343319539912 / standard deviation (unweighted) of fiber number
# NRES    = ' 5.00 4.25 3.50'    / number of pixels/resolution used for sinc
# MIN_H   =                  7.0 / minimum H mag of cohort
# MAX_H   =    12.19999980926514 / maximum H mag of cohort
# MIN_JK  =    0.300000011920929 / minimum J-K of cohort
# MAX_JK  =       9999.990234375 / maximum J-K of cohort
# RMIN    =                 6247 / Min pixel of red chip contrib, any frame
# RMAX    =                 8352 / Maxmm pixel of red chip contrib, any frame
# GMIN    =                 3465 / Min pixel of green chip contrib, any frame
# GMAX    =                 6076 / Maxm pixel of green chip contrib, any frame
# BMIN    =                  106 / Min pixel of blue chip contrib, any frame
# BMAX    =                 3248 / Maxm pixel of blue chip contrib, any frame
# ROVERMIN=                 6249 / Min pixel of red chip contrib, all frames
# ROVERMAX=                 8349 / Max pixel of red chip contrib, all frames
# GOVERMIN=                 3467 / Min pixel of green chip contrib, all frames
# GOVERMAX=                 6074 / Max pixel of green chip contrib, all frames
# BOVERMIN=                  107 / Minimum pixel of blue chip contrib, all frames
# BOVERMAX=                 3247 / Maximum pixel of blue chip contrib, all frames
# COMMENT VISIT 1 INFORMATION
# SFILE1  = 'asVisit-dr17-10085-58027-051.fits' /  Visit #1 spectrum file
# DATE1   = '2017-10-01T04:17:06.818' / DATE-OBS of visit 1
# JD1     =        2458027.70173 / Julian date of visit 1
# FIBER1  =                   51 / Fiber, visit 1
# BC1     =   -9.760631561279297 / Barycentric correction (km/s), visit 1
# VRAD1   =    166.4251070025184 / Radial velocity (km/s) of visit 1
# VERR1   =   0.0307622624460203 / Uncertainty in radial velocity (km/s)
# VHELIO1 =    156.6644754412391 / Barycentric velocity (km/s), visit 1
# SNRVIS1 =    177.6324140304731 / Median S/N per apStar pixel,, visit 1
# FLAG1   =                    0 / STARFLAG for visit 1
# COMMENT VISIT 2 INFORMATION
# SFILE2  = 'asVisit-dr17-10085-58056-046.fits' /  Visit #2 spectrum file
# DATE2   = '2017-10-30T03:40:11.304' / DATE-OBS of visit 2
# JD2     =         2458056.6587 / Julian date of visit 2
# FIBER2  =                   46 / Fiber, visit 2
# BC2     =   -11.86082553863525 / Barycentric correction (km/s), visit 2
# VRAD2   =    168.2793903977543 / Radial velocity (km/s) of visit 2
# VERR2   =  0.03641455678464122 / Uncertainty in radial velocity (km/s)
# VHELIO2 =     156.418564859119 / Barycentric velocity (km/s), visit 2
# SNRVIS2 =     152.989727898749 / Median S/N per apStar pixel,, visit 2
# FLAG2   =                    0 / STARFLAG for visit 2
# COMMENT VISIT 3 INFORMATION
# SFILE3  = 'asVisit-dr17-10085-58059-004.fits' /  Visit #3 spectrum file
# DATE3   = '2017-11-02T02:50:00.496' / DATE-OBS of visit 3
# JD3     =        2458059.64124 / Julian date of visit 3
# FIBER3  =                    4 / Fiber, visit 3
# BC3     =   -11.89357471466064 / Barycentric correction (km/s), visit 3
# VRAD3   =     168.363107209485 / Radial velocity (km/s) of visit 3
# VERR3   =  0.02965902789319023 / Uncertainty in radial velocity (km/s)
# VHELIO3 =    156.4695324948244 / Barycentric velocity (km/s), visit 3
# SNRVIS3 =    198.3521695813443 / Median S/N per apStar pixel,, visit 3
# FLAG3   =                    0 / STARFLAG for visit 3
# HISTORY APOGEE Reduction Pipeline Version: 0.17.22
# HISTORY HDU0 : header
# HISTORY HDU1 : flux
# HISTORY HDU2 : flux uncertainty
# HISTORY HDU3 : pixel bitmask
# HISTORY HDU4 : sky
# HISTORY HDU5 : sky uncertainty
# HISTORY HDU6 : telluric
# HISTORY HDU7 : telluric uncertainty
# HISTORY HDU8 : LSF table
# HISTORY HDU9 : RV table
# HISTORY HDU10 : RV table for combined spectrum

# %%
plt.plot(hdu[1].data[0])
