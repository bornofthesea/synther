# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e8'
observed = 'e8.dat'
rv = -83

# %% [markdown]
# Teff 4762 logg 1.48 vmicro 2.0

# %%
# Original APSCAP parameters
speclist = ["e8.dat","e8-1.dat"]
label = ["apo","C=0.25,O=0.25"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.16, ncorr1=1.2,
    yoffset2=0.13, ncorr2=1.2,
    yoffset3=0.15, ncorr3=1.2,
    ylim1=(0.88,1.03),
    ylim2=(0.83,1.08),
    ylim3=(0.93,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e8_cno.png')

# %%
speclist = ["e8p.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    ylim1 = (0.88, 1.03), ylim2 = (0.73, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e8_p.png')

# %%
speclist = ["e8sk.dat"]
label = ['S=0.12']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.16, ncorr1=1.2,
    yoffset2=0.16, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e8sk.dat"]
label = ['K=-0.18']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e8_k.png')

# %%
speclist = ["e8ce.dat"]
label = ['[Ce/Fe] = -0.42']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.16, ncorr2=1.2,
    yoffset3=0.16, ncorr3=1.2,
    yoffset4=0.15, ncorr4=1.2,
    yoffset5=0.16, ncorr5=1.2,
    yoffset6=0.15, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e8_ce.png')
