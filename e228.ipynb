# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e228'
observed = 'e228.dat'

# %% [markdown]
# Teff 4207 logg 1.2 vmicro 2.081
#
# Noisy spectra, hard to fit CNO
#
# PSK seems fine as far as it is possible to see

# %%
# Original APSCAP parameters
speclist = ["e228xall.dat"]
label = ["[C/Fe] = -0.39, [N/Fe] = -0.04, [O/Fe] = 0.01"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17, yoffset1=0.14, ncorr1=1.2,
    xoffset2=-17.2, yoffset2=0.13, ncorr2=1.2,
    xoffset3=-17.2, yoffset3=0.14, ncorr3=1.2,
    ylim1=(0.8,1.03),
    ylim2=(0.7,1.03),
    ylim3=(0.8,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e228_cno.png')

# %%
# Zoom out
speclist = ["e228xall.dat"]
label = ["[C/Fe] = -0.11, [N/Fe] = 0.00, [O/Fe] = -0.22"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17, yoffset1=0.14, ncorr1=1.2,
    xoffset2=-17.2, yoffset2=0.14, ncorr2=1.2,
    xoffset3=-17.2, yoffset3=0.14, ncorr3=1.2,
    xlim1=(15501,15530),
    xlim2=(15535,15570),
    xlim3=(15570,15599),
    ylim1=(0,6),
    ylim2=(0,6),
    ylim3=(0,6)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e228_cno.png')

# %%
speclist = ["e228xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17.2, yoffset1=0.10, ncorr1=1.2,
    xoffset2=-18.2, yoffset2=0.13, ncorr2=1.2,
    ylim1 = (0.78, 1.1), ylim2 = (0.68, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e228_p.png')

# %%
speclist = ["e228xb.dat"]
label = ['[S/Fe] = -0.24']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-16.8, yoffset1=0.15, ncorr1=1.2,
    xoffset2=-16.9, yoffset2=0.135, ncorr2=1.2,
    ylim1 = (0.88, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e228xb.dat"]
label = ['[K/Fe] = -0.06']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-16.8, yoffset1=0.11, ncorr1=1.2,
    ylim1 = (0.83, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e228_k.png')

# %%
speclist = ["e228xa.dat"]
label = ['[Ce/Fe] = 0.01']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-17.3, yoffset1=0.13, ncorr1=1.2,
    xoffset2=-17.6, yoffset2=0.17, ncorr2=1.2,
    xoffset3=-18, yoffset3=0.15, ncorr3=1.2,
    xoffset4=-18.2, yoffset4=0.15, ncorr4=1.2,
    xoffset5=-18.5, yoffset5=0.17, ncorr5=1.2,
    xoffset6=-18.5, yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.71,1.11),
    ylim2=(0.56,1.11),
    ylim3=(0.71,1.06),
    ylim4=(0.63,1.06),
    ylim5=(0.83,1.06),
    ylim6=(0.56,1.01)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e228_ce.png')
