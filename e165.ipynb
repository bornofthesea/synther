# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e165'
observed = 'e165.dat'

# %% [markdown]
# Teff 4579.838 logg 2.013 vmicro 0.327

# %%
speclist = ["e165xall.dat"]  # Your synthetic files
label = ["[C/Fe] = -0.27, [N/Fe] = 0.26, [O/Fe] = 0.15"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e165.dat",
    labels=label,
    starname="e165",
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-12.2, yoffset2=0.16, ncorr2=1.2,
    xoffset3=-12.5, yoffset3=0.13, ncorr3=1.2,
    ylim1=(0.8, 1.1), 
    ylim2=(0.8, 1.1), 
    ylim3=(0.8, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_cno.png')

# %%
speclist = ["e165xall.dat"]  # Your synthetic files
label = ["[C/Fe] = -0.27, [N/Fe] = 0.26, [O/Fe] = 0.15"]    # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e165.dat",
    labels=label,
    starname="e165",
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-12.5, yoffset2=0.16, ncorr2=1.2,
    xoffset3=-12.5, yoffset3=0.16, ncorr3=1.2,
    xlim1=(15501,15530),
    xlim2=(15535,15570),
    xlim3=(15570,15599),
    ylim1=(0.8, 1.1), 
    ylim2=(0.8, 1.1), 
    ylim3=(0.8, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_cno.png')

# %%
speclist = ["e165xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-13.0, yoffset1=0.17, ncorr1=1.2,
    xoffset2=-13.4, yoffset2=0.19, ncorr2=1.2,
    ylim1 = (0.9, 1.1), ylim2 = (0.8, 1.3)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_p.png')

# %%
speclist = ["e165xb.dat"]
label = ['[S/Fe] = 0.01']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-13.4, yoffset2=0.16, ncorr2=1.2,
    ylim1 = (0.93, 1.03), ylim2 = (0.88, 1.1)
)

speclist = ["e165xb.dat"]
label = ['[K/Fe] = -0.06']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.3, yoffset1=0.15, ncorr1=1.2,
    ylim1 = (0.93, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_k.png')

# %%
speclist = ["e165xa.dat"]
label = ['[Ce/Fe] = 1.64']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-12.5, yoffset1=0.0, ncorr1=1.2,
    xoffset2=-13.1, yoffset2=0.165, ncorr2=1.2,
    xoffset3=-13.4, yoffset3=0.13, ncorr3=1.2,
    xoffset4=-13.3, yoffset4=0.18, ncorr4=1.2,
    xoffset5=-13.9, yoffset5=0.18, ncorr5=1.2,
    xoffset6=-13.8, yoffset6=0.16, ncorr6=1.2,
    ylim1=(0.63,1.43),
    ylim2=(0.51,1.43),
    ylim3=(0.81,1.31),
    ylim4=(0.68,1.13),
    ylim5=(0.78,1.08),
    ylim6=(0.68,1.08)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_ce.png')
