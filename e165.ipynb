# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir

# %%
speclist = ["e165xall.dat"]  # Your synthetic files
label = ["C712 N707 O775"]   # Your model labels

plot_nir(
    synthetic_files=speclist,
    observed_file="e165_1.dat",
    labels=label,
    starname="e165",
    figsize=(5,6),
    xoffset1=-7.65, yoffset1=-0.005, ncorr1=1,
    xoffset2=-7.65, yoffset2=-0.025, ncorr2=1,
    xoffset3=-7.65, yoffset3=-0.015, ncorr3=1,
    ylim1=(0.8, 1.1), 
    ylim2=(0.8, 1.1), 
    ylim3=(0.8, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_all.png')

# %%
speclist = ["e165xall.dat"]  # Your synthetic files
label = ["C712 N707 O775"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e165.dat",
    labels=label,
    starname="e165",
    figsize=(5,6),
    xoffset1=-7.65, yoffset1=-0.005, ncorr1=1,
    xoffset2=-7.65, yoffset2=-0.025, ncorr2=1,
    xoffset3=-7.65, yoffset3=-0.015, ncorr3=1,
    ylim1=(0.8, 1.1), 
    ylim2=(0.8, 1.1), 
    ylim3=(0.8, 1.1)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e165_cno.png')
