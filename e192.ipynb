# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir
starname = 'e192'
observed = 'e192.dat'

# %% [markdown]
# Teff 4511 logg 2.029 vmicro 1.495
#
# [C/Fe] = 0.05, [N/Fe] = 0.09, [O/Fe] = 0.53
#
# [S/Fe] = 0.15, less than ASPCAP

# %%
# Original APSCAP parameters
speclist = ["e192xall.dat"]
label = ["[C/Fe] = 0.05, [N/Fe] = 0.09, [O/Fe] = 0.34"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.98, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.1, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-7.0, yoffset3=0.135, ncorr3=1.2,
    ylim1=(0.80,1.1),
    ylim3=(0.88,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e192_cno.png')

# %%
speclist = ["e192xall-1.dat"]
label = ["[C/Fe] = 0.15, [N/Fe] = 0.09, [O/Fe] = 0.34"]


plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.98, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.1, yoffset2=0.135, ncorr2=1.2,
    xoffset3=-7.0, yoffset3=0.135, ncorr3=1.2,
    ylim1=(0.80,1.03),
    ylim3=(0.88,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e192_cno.png')

# %%
speclist = ["e192xall-3.dat"]
label = ["[C/Fe] = 0.10, [N/Fe] = 0.09, [O/Fe] = 0.23"]


plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.98, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.1, yoffset2=0.135, ncorr2=1.2,
    xoffset3=-7.1, yoffset3=0.14, ncorr3=1.2,
    ylim1=(0.80,1.1),
    ylim3=(0.88,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e192_cno.png')

# %%
speclist = ["e192xall-2.dat"]
label = ["[C/Fe] = 0.05, [N/Fe] = 0.09, [O/Fe] = 0.53"]
#C793 N739 O863

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.98, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.1, yoffset2=0.135, ncorr2=1.2,
    xoffset3=-7.15, yoffset3=0.142, ncorr3=1.2,
    ylim1=(0.80,1.1),
    ylim3=(0.88,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e192_cno.png')

# %%
speclist = ["e192xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.2, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.55, yoffset2=0.15, ncorr2=1.2,
    ylim1 = (0.75, 1.05), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e192_p.png')

# %%
speclist = ["e192xb.dat", "e192xb-1.dat"]
label = ['[S/Fe] = 0.45', '[S/Fe] = 0.15']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.0, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-6.95, yoffset2=0.15, ncorr2=1.2,
    ylim1 = (0.93, 1.03), ylim2 = (0.88, 1.03)
)

speclist = ["e192xb.dat"]
label = ['[K/Fe] = 0.25']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.85, yoffset1=0.145, ncorr1=1.2,
    ylim1 = (0.83, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e192_k.png')
