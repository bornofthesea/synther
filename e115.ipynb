# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e115'
observed = 'e115.dat'

# %% [markdown]
# Teff 4681.354 logg 1.938 vmicro 1.698
#
# Fitted with more C

# %%
# Original APSCAP parameters
speclist = ["e115xall.dat"]
label = ["[C/Fe] = -0.13, [N/Fe] = 0.03, [O/Fe] = 0.41"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.1, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-7.1, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-7.1, yoffset3=0.16, ncorr3=1.2,
    ylim1=(0.9,1.03),
    ylim3=(0.9,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_cno.png')

# %%
speclist = ["e115xall.dat", "e115xall-1.dat"]
label = ["[C/Fe] = -0.13, [N/Fe] = 0.03, [O/Fe] = 0.41", "[C/Fe] = 0.07, [N/Fe] = 0.03, [O/Fe] = 0.41"]
#label = ["C752 N689 O807"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.1, yoffset1=0.16, ncorr1=1.2,
    xoffset2=-7.1, yoffset2=0.15, ncorr2=1.2,
    xoffset3=-7.1, yoffset3=0.1575, ncorr3=1.2,
    ylim1=(0.9,1.03),
    ylim3=(0.93,1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_cno.png')

# %%
speclist = ["e115xa.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.3, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.5, yoffset2=0.16, ncorr2=1.2,
    ylim1 = (0.91, 1.01), ylim2 = (0.81, 1.01)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_p.png')

# %%
speclist = ["e115xb.dat"]
label = ['[S/Fe] = 0.44']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.0, yoffset1=0.155, ncorr1=1.2,
    xoffset2=-6.9, yoffset2=0.163, ncorr2=1.2,
    ylim1 = (0.91, 1.01), ylim2 = (0.91, 1.01)
)

speclist = ["e115xb.dat"]
label = ['[K/Fe] = 0.28']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-6.9, yoffset1=0.155, ncorr1=1.2,
    ylim1 = (0.91, 1.01)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_k.png')

# %%
speclist = ["e115xa.dat"]
label = ['[Ce/Fe] = -0.09']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-7.3, yoffset1=0.145, ncorr1=1.2,
    xoffset2=-7.3, yoffset2=0.165, ncorr2=1.2,
    xoffset3=-7.4, yoffset3=0.165, ncorr3=1.2,
    xoffset4=-7.4, yoffset4=0.155, ncorr4=1.2,
    xoffset5=-7.4, yoffset5=0.165, ncorr5=1.2,
    xoffset6=-7.6, yoffset6=0.1625, ncorr6=1.2,
    ylim1=(0.73,1.08),
    ylim2=(0.61,1.13),
    ylim3=(0.78,1.08),
    ylim4=(0.68,1.13),
    ylim5=(0.78,1.08),
    ylim6=(0.68,1.08)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e115_ce.png')
