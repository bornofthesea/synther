# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_ce
starname = 'e224'
observed = 'e224.dat'

# %% [markdown]
# Teff 4600 logg 2.46 vmicro 1.24
#
# C/Fe = -0.22 N/Fe = 0.39 O/Fe = 0.04
#
# S/Fe = 0.11 K/Fe = -0.06

# %%
speclist = ["e224xall-1.dat"]  # Your synthetic files
label = ["[C/Fe] = -0.22, [N/Fe] = 0.40, [O/Fe] = 0.04"]
#label = ["C858 N861 O905"]   # Your model labels

plot_cno(
    synthetic_files=speclist,
    observed_file="e224.dat",
    labels=label,
    starname="e224",
    figsize=(5,6),
    xoffset1=-4.05, yoffset1=-0.06, ncorr1=1,
    xoffset2=-4.1, yoffset2=-0.09, ncorr2=1,
    xoffset3=-4.1, yoffset3=-0.065, ncorr3=1,
    ylim1=(0.65, 1.03), 
    ylim2=(0.65, 1.03), 
    ylim3=(0.70, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e224_cno.png')

# %%
speclist = ["e224xa.dat"]
starname = 'e224'
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file="e224.dat",
    labels=label,
    starname="e224",
    figsize=(5,6),
    xoffset1 = -4.2, yoffset1 = 0.11, ncorr1 = 1.2, 
    xoffset2 = -4.4, yoffset2 = 0.11, ncorr2 = 1.2,
    ylim1 = (0.66, 1.06), ylim2 = (0.65, 1.05)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e224_p.png')

# %%
speclist = ["e224xb.dat"]
label = ['[S/Fe] = 0.01']
plot_sulfur(
    synthetic_files=speclist,
    observed_file="e224.dat",
    labels=label,
    starname="e224",
    figsize=(5,6),
    xoffset1 = -4.0, yoffset1 = 0.11, ncorr1 = 1.2, 
    xoffset2 = -4.0, yoffset2 = 0.11, ncorr2 = 1.2,
    ylim1 = (0.80, 1.05), ylim2 = (0.70, 1.05)
)

speclist = ["e224xb.dat"]
label = ['[K/Fe] = -0.06']
plot_potassium(
    synthetic_files=speclist,
    observed_file="e224.dat",
    labels=label,
    starname="e224",
    figsize=(5,6),
    xoffset1 = -4.0, yoffset1 = 0.04, ncorr1 = 1.2,
    ylim1 = (0.59, 1.03)
)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e224_k.png')

# %%
speclist = ["e224xa.dat"]
label = ['[Ce/Fe] = -0.18']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    xoffset1=-4.2, yoffset1=0.05, ncorr1=1.2,
    xoffset2=-4.2, yoffset2=0.09, ncorr2=1.2,
    xoffset3=-4.3, yoffset3=0.11, ncorr3=1.2,
    xoffset4=-4.3, yoffset4=0.10, ncorr4=1.2,
    xoffset5=-4.4, yoffset5=0.11, ncorr5=1.2,
    xoffset6=-4.5, yoffset6=0.11, ncorr6=1.2,
    ylim1=(0.71,1.01),
    ylim2=(0.56,1.01),
    ylim3=(0.73,1.01),
    ylim4=(0.63,1.01),
    ylim5=(0.83,1.01),
    ylim6=(0.56,1.01)

)
# Out:
# PosixPath('/home/morgan/stellar_analysis/plots/e224_ce.png')
