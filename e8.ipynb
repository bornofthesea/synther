# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e7'
observed = 'e7.dat'
rv = -83

# %% [markdown]
# Teff 4271 logg 0.75 vmicro 3.751

# %%
# Original APSCAP parameters
speclist = ["e7.dat", "e7-1.dat"]
label = ["apo", "C=0.10,N=0,O=0.20"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.16, ncorr1=1.2,
    yoffset2=0.1, ncorr2=1.2,
    yoffset3=0.12, ncorr3=1.2,
    ylim1=(0.63,1.03),
    ylim2=(0.63,1.03),
    ylim3=(0.73,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e7_cno.png')

# %%
speclist = ["e7p.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.13, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.73, 1.03), ylim2 = (0.73, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e7_p.png')

# %%
speclist = ["e7sk.dat", "e7sk-1.dat"]
label = ['apo', 'S=0']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e7sk.dat", "e7sk-1.dat"]
label = ['apo', 'K=0']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.12, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e7_k.png')

# %%
speclist = ["e7ce.dat","e7ce-1.dat"]
label = ['[Ce/Fe] = 0.01','[Ce/Fe] = 0.50']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.05, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    yoffset4=0.13, ncorr4=1.2,
    yoffset5=0.14, ncorr5=1.2,
    yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e7_ce.png')
