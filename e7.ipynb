# %%
from stellar_analysis import plot_cno, plot_phosphorus, plot_potassium, plot_sulfur, plot_nir, plot_ce
starname = 'e6'
observed = 'e6.dat'
rv = -83

# %% [markdown]
# Teff 4070 logg 0.52 vmicro 2.49

# %%
# Original APSCAP parameters
speclist = ["e6-1.dat"]
label = ["C=-0.15,N=0.2,O=0.4"]

plot_cno(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.145, ncorr1=1.2,
    yoffset2=0.13, ncorr2=1.2,
    yoffset3=0.145, ncorr3=1.2,
    ylim1=(0.63,1.03),
    ylim2=(0.63,1.03),
    ylim3=(0.83,1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e6_cno.png')

# %%
speclist = ["e6p.dat"]
label = ['[P/Fe] = 0.0']
plot_phosphorus(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    yoffset2=0.14, ncorr2=1.2,
    ylim1 = (0.73, 1.03), ylim2 = (0.73, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e6_p.png')

# %%
speclist = ["e6sk.dat", "e6sk-1.dat"]
label = ['[S/Fe] = 0.14', '[S/Fe] = 0']
plot_sulfur(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.15, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    ylim1 = (0.83, 1.03), ylim2 = (0.83, 1.03)
)

speclist = ["e6sk.dat", "e6sk-1.dat"]
label = ['[K/Fe] = 0.2', '[K/Fe] = 0']
plot_potassium(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.14, ncorr1=1.2,
    ylim1 = (0.68, 1.03)
)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e6_k.png')

# %%
speclist = ["e6ce.dat","e6ce-1.dat"]
label = ['[Ce/Fe] = 0.0','[Ce/Fe] = 0.6']
plot_ce(
    synthetic_files=speclist,
    observed_file=observed,
    labels=label,
    starname=starname,
    figsize=(5,6),
    rvoffset = rv,
    yoffset1=0.09, ncorr1=1.2,
    yoffset2=0.15, ncorr2=1.2,
    yoffset3=0.14, ncorr3=1.2,
    yoffset4=0.14, ncorr4=1.2,
    yoffset5=0.14, ncorr5=1.2,
    yoffset6=0.14, ncorr6=1.2,
    ylim1=(0.53,1.08),
    ylim2=(0.53,1.03),
    ylim3=(0.53,1.03),
    ylim4=(0.53,1.03),
    ylim5=(0.53,1.03),
    ylim6=(0.53,1.03)

)
# Out:
# PosixPath('/home/morgan/PhD/Scripts/synther/plots/e6_ce.png')
